# %% [markdown]
# <a href="https://colab.research.google.com/github/GBertolaccini/Introducao_Ciencia_Dados_POS/blob/main/Aula_01_e_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Instalando Pandas profiling
# !pip install -U pandas-profiling
# Out:
# ...
#      |████████████████████████████████| 256kB 4.2MB/s
# ...
#      |████████████████████████████████| 10.1MB 39.6MB/s
# ...
#      |████████████████████████████████| 1.1MB 42.8MB/s
# ...
#      |████████████████████████████████| 81kB 9.5MB/s
# ...
#      |████████████████████████████████| 112kB 51.5MB/s
# ...
#      |████████████████████████████████| 3.1MB 44.7MB/s
# ...
#      |████████████████████████████████| 61kB 7.0MB/s
# ...
#      |████████████████████████████████| 645kB 37.6MB/s
# ...
#      |████████████████████████████████| 296kB 41.0MB/s
# ...
#   Created wheel for phik: filename=phik-0.11.2-cp37-none-any.whl size=1107413 sha256=9f849c6a28753ffa59b9947d7142b3998e758164f69ca930c6fb8b8975ac4b8f
#   Stored in directory: /root/.cache/pip/wheels/c0/a3/b0/f27b1cfe32ea131a3715169132ff6d85653789e80e966c3bf6
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-cp37-none-any.whl size=27085 sha256=2cef617be4aa5bd0401578bc07a205492dd0b46cbcefec6a8df946d3c37d61b3
# ...

# %%
import pandas as pd

# %%
path_dir = '/content/drive/MyDrive/Colab Notebooks/[POS GRADUACAO]/1 - Fundamentos em Ciências de Dados e Inteligência Artificial/1.3 - Introducao a Ciencia de Dados/Datasets'

df_customers = pd.read_csv( path_dir + '/olist_customers_dataset.csv')
df_geo = pd.read_csv(path_dir + '/olist_geolocation_dataset.csv', encoding='utf8')
df_order_items = pd.read_csv(path_dir + '/olist_order_items_dataset.csv')
df_order_pay = pd.read_csv(path_dir + '/olist_order_payments_dataset.csv')
df_reviews = pd.read_csv(path_dir + '/olist_order_reviews_dataset.csv')
df_order = pd.read_csv(path_dir + '/olist_orders_dataset.csv')
df_products = pd.read_csv(path_dir + '/olist_products_dataset.csv')
df_sellers = pd.read_csv(path_dir + '/olist_sellers_dataset.csv')

# %%
df_customers.head(3)
# Out:
#                         customer_id  ... customer_state
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  ...             SP
# 1  18955e83d337fd6b2def6b18a428ac77  ...             SP
# 2  4e7b3e00288586ebd08712fdd0374a03  ...             SP
#
# [3 rows x 5 columns]

# %%
df_order.head(3)
# Out:
#                            order_id  ... order_estimated_delivery_date
# 0  e481f51cbdc54678b7cc49136f2d6af7  ...           2017-10-18 00:00:00
# 1  53cdb2fc8bc7dce0b6741e2150273451  ...           2018-08-13 00:00:00
# 2  47770eb9100c2d0c44946d9cf07ec65d  ...           2018-09-04 00:00:00
#
# [3 rows x 8 columns]

# %%
df_order_pay.head(3)
# Out:
#                            order_id  ...  payment_value
# 0  b81ef226f3fe1789b1e8b2acac839d17  ...          99.33
# 1  a9810da82917af2d9aefd1278f1dcfa0  ...          24.39
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd  ...          65.71
#
# [3 rows x 5 columns]

# %%
df_order_items.head(3)
# Out:
#                            order_id  order_item_id  ...  price freight_value
# 0  00010242fe8c5a6d1ba2dd792cb16214              1  ...   58.9         13.29
# 1  00018f77f2f0320c557190d7a144bdd3              1  ...  239.9         19.93
# 2  000229ec398224ef6ca0657da4fc703e              1  ...  199.0         17.87
#
# [3 rows x 7 columns]

# %%
df_sellers.head(3)
# Out:
#                           seller_id  ...  seller_state
# 0  3442f8959a84dea7ee197c632cb2df15  ...            SP
# 1  d1b65fc7debc3361ea86b5f14c68d2e2  ...            SP
# 2  ce3ad9de960102d0677a81f5d0bb7b2d  ...            RJ
#
# [3 rows x 4 columns]

# %%
df_products.head(3)
# Out:
#                          product_id  ... product_width_cm
# 0  1e9e8ef04dbcff4541ed26657ea517e5  ...             14.0
# 1  3aa071139cb16b67ca9e5dea641aaa2f  ...             20.0
# 2  96bd76ec8810374ed1b65e291975717f  ...             15.0
#
# [3 rows x 9 columns]
